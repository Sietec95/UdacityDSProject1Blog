# %% [markdown]
# ## Business Understanding
# AirBnb from the standpoint of a (potential) host. Want to get into the market with maximum earning potential.
# - What are the main factors that determine the price of a stay at an AirBnb?
# - What are the main factors that determine the occupancy rate?
# - How can the revenue generated by an AirBnb be maximized?
#     - Which improvements can be made at a low cost and without changing fixed conditions (e.g. no. of bedrooms)?
#     - Does it make more sense to have short or long term visits (total time and monetary cost for cleaning, fees, etc. vs. earnings)?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
calendar = pd.read_csv('./data/calendar.csv')
listings = pd.read_csv('./data/listings.csv')
reviews = pd.read_csv('./data/reviews.csv')
